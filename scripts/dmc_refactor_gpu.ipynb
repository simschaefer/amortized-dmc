# %%
import sys
sys.path.append("../../BayesFlow")
sys.path.append("../")

import os
if "KERAS_BACKEND" not in os.environ:
    # set this to "torch", "tensorflow", or "jax"
    os.environ["KERAS_BACKEND"] = "torch"

import numpy as np
import pickle

import keras

# %%
import bayesflow as bf
from dmc import DMC

# %% [markdown]
# ## Create Simulator

# %%
simulator = DMC(
    prior_means=np.array([16., 111., 0.5, 322., 75.]), 
    prior_sds=np.array([10., 47., 0.13, 40., 23.]),
    tmax=1500,
    contamination_probability=.05
)

# %%
sims = simulator.sample(10)
for k, v in sims.items():
    print(f"Shape of {k}: {v.shape}")
# Out:
# Shape of A: (10, 1)
# Shape of tau: (10, 1)
# Shape of mu_c: (10, 1)
# Shape of t0: (10, 1)
# Shape of b: (10, 1)
# Shape of rt: (10, 200, 1)
# Shape of accuracy: (10, 200, 1)
# Shape of conditions: (10, 200, 1)
# Shape of num_obs: (10, 1)

# %% [markdown]
# ## Create Adapter

# %%
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    .sqrt("num_obs")
    .concatenate(["A", "tau", "mu_c", "t0", "b"], into="inference_variables")
    .concatenate(["rt", "accuracy", "conditions"], into="summary_variables")
    .standardize(include="inference_variables")
    .rename("num_obs", "inference_conditions")
)

# %%
for k, v in adapter(sims).items():
    print(f"Shape of {k}: {v.shape}")
# Out:
# Shape of inference_variables: (10, 5)
# Shape of summary_variables: (10, 200, 3)
# Shape of inference_conditions: (10, 1)

# %% [markdown]
# ## Create Networks and Workflow

# %%
inference_net = bf.networks.CouplingFlow(coupling_kwargs=dict(subnet_kwargs=dict(dropout=0.1)))

# inference_net = bf.networks.FlowMatching(subnet_kwargs=dict(dropout=0.1))

summary_net = bf.networks.SetTransformer(summary_dim=32, num_seeds=2, dropout=0.1)

workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    initial_learning_rate=1e-4,
    inference_network=inference_net,
    summary_network=summary_net,
    checkpoint_filepath='../checkpoints',
    checkpoint_name= "simons_crazy_net_batchsize32",
    inference_variables=["A", "tau", "mu_c", "t0", "b"]
)

# %% [markdown]
# ## Generate Data and Train Offline

# %%
file_path = '../data/data_offline_training/data_offline_training.pickle'

# train_data = simulator.sample(50000)

# with open(file_path, 'wb') as file:
#     pickle.dump(train_data, file)

with open(file_path, 'rb') as file:
    train_data = pickle.load(file)

# %%
    
val_file_path = '../data/data_offline_training/data_offline_validation.pickle'

with open(val_file_path, 'rb') as file:
    val_data = pickle.load(file)

# %%
# %%time
history = workflow.fit_offline(train_data, epochs=100, batch_size=32, validation_data=val_data)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 5.2603 - loss/inference_loss: 5.2603 - val_loss: 5.4549 - val_loss/inference_loss: 5.4549
# Epoch 2/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 4.3199 - loss/inference_loss: 4.3199 - val_loss: 4.7238 - val_loss/inference_loss: 4.7238
# Epoch 3/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 3.5177 - loss/inference_loss: 3.5177 - val_loss: 5.9437 - val_loss/inference_loss: 5.9437
# Epoch 4/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 2.6293 - loss/inference_loss: 2.6293 - val_loss: 4.6273 - val_loss/inference_loss: 4.6273
# Epoch 5/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 2.2472 - loss/inference_loss: 2.2472 - val_loss: 7.9079 - val_loss/inference_loss: 7.9079
# Epoch 6/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - loss: 1.9951 - loss/inference_loss: 1.9951 - val_loss: 5.7534 - val_loss/inference_loss: 5.7534
# Epoch 7/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - loss: 1.8524 - loss/inference_loss: 1.8524 - val_loss: 3.3367 - val_loss/inference_loss: 3.3367
# Epoch 8/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - loss: 1.7214 - loss/inference_loss: 1.7214 - val_loss: 5.2847 - val_loss/inference_loss: 5.2847
# Epoch 9/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - loss: 1.5746 - loss/inference_loss: 1.5746 - val_loss: 4.8909 - val_loss/inference_loss: 4.8909
# Epoch 10/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - loss: 1.4843 - loss/inference_loss: 1.4843 - val_loss: 2.0242 - val_loss/inference_loss: 2.0242
# Epoch 11/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - loss: 1.2865 - loss/inference_loss: 1.2865 - val_loss: 3.8303 - val_loss/inference_loss: 3.8303
# Epoch 12/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 65ms/step - loss: 1.1575 - loss/inference_loss: 1.1575 - val_loss: 3.9689 - val_loss/inference_loss: 3.9689
# Epoch 13/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - loss: 1.0801 - loss/inference_loss: 1.0801 - val_loss: 4.6932 - val_loss/inference_loss: 4.6932
# Epoch 14/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 1.0134 - loss/inference_loss: 1.0134 - val_loss: 3.2522 - val_loss/inference_loss: 3.2522
# Epoch 15/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 0.9546 - loss/inference_loss: 0.9546 - val_loss: 2.4519 - val_loss/inference_loss: 2.4519
# Epoch 16/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.9149 - loss/inference_loss: 0.9149 - val_loss: 2.7408 - val_loss/inference_loss: 2.7408
# Epoch 17/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 63ms/step - loss: 0.8882 - loss/inference_loss: 0.8882 - val_loss: 4.4765 - val_loss/inference_loss: 4.4765
# Epoch 18/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.7929 - loss/inference_loss: 0.7929 - val_loss: 2.4710 - val_loss/inference_loss: 2.4710
# Epoch 19/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.8028 - loss/inference_loss: 0.8028 - val_loss: 1.4158 - val_loss/inference_loss: 1.4158
# Epoch 20/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 0.7617 - loss/inference_loss: 0.7617 - val_loss: 1.2424 - val_loss/inference_loss: 1.2424
# Epoch 21/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 0.6878 - loss/inference_loss: 0.6878 - val_loss: 1.2879 - val_loss/inference_loss: 1.2879
# Epoch 22/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.7008 - loss/inference_loss: 0.7008 - val_loss: 2.7174 - val_loss/inference_loss: 2.7174
# Epoch 23/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.6592 - loss/inference_loss: 0.6592 - val_loss: 1.6887 - val_loss/inference_loss: 1.6887
# Epoch 24/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.6704 - loss/inference_loss: 0.6704 - val_loss: 1.1285 - val_loss/inference_loss: 1.1285
# Epoch 25/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.6281 - loss/inference_loss: 0.6281 - val_loss: 1.1438 - val_loss/inference_loss: 1.1438
# Epoch 26/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.5994 - loss/inference_loss: 0.5994 - val_loss: 1.8400 - val_loss/inference_loss: 1.8400
# Epoch 27/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.6150 - loss/inference_loss: 0.6150 - val_loss: 1.0586 - val_loss/inference_loss: 1.0586
# Epoch 28/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 35s 90ms/step - loss: 0.5593 - loss/inference_loss: 0.5593 - val_loss: 1.5581 - val_loss/inference_loss: 1.5581
# Epoch 29/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 49s 126ms/step - loss: 0.5345 - loss/inference_loss: 0.5345 - val_loss: 1.0596 - val_loss/inference_loss: 1.0596
# Epoch 30/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 32s 81ms/step - loss: 0.5088 - loss/inference_loss: 0.5088 - val_loss: 1.0030 - val_loss/inference_loss: 1.0030
# Epoch 31/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.4988 - loss/inference_loss: 0.4988 - val_loss: 1.2821 - val_loss/inference_loss: 1.2821
# Epoch 32/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 49s 124ms/step - loss: 0.4728 - loss/inference_loss: 0.4728 - val_loss: 2.6657 - val_loss/inference_loss: 2.6657
# Epoch 33/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 48s 124ms/step - loss: 0.4483 - loss/inference_loss: 0.4483 - val_loss: 0.9649 - val_loss/inference_loss: 0.9649
# Epoch 34/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 49s 126ms/step - loss: 0.4761 - loss/inference_loss: 0.4761 - val_loss: 1.1893 - val_loss/inference_loss: 1.1893
# Epoch 35/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 49s 126ms/step - loss: 0.4306 - loss/inference_loss: 0.4306 - val_loss: 1.3939 - val_loss/inference_loss: 1.3939
# Epoch 36/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 50s 128ms/step - loss: 0.3905 - loss/inference_loss: 0.3905 - val_loss: 1.0378 - val_loss/inference_loss: 1.0378
# Epoch 37/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 50s 127ms/step - loss: 0.4460 - loss/inference_loss: 0.4460 - val_loss: 1.1425 - val_loss/inference_loss: 1.1425
# Epoch 38/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 50s 128ms/step - loss: 0.4162 - loss/inference_loss: 0.4162 - val_loss: 1.3402 - val_loss/inference_loss: 1.3402
# Epoch 39/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - loss: 0.4169 - loss/inference_loss: 0.4169 - val_loss: 1.5009 - val_loss/inference_loss: 1.5009
# Epoch 40/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 63ms/step - loss: 0.3994 - loss/inference_loss: 0.3994 - val_loss: 0.9959 - val_loss/inference_loss: 0.9959
# Epoch 41/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.3357 - loss/inference_loss: 0.3357 - val_loss: 1.3306 - val_loss/inference_loss: 1.3306
# Epoch 42/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.3387 - loss/inference_loss: 0.3387 - val_loss: 2.1443 - val_loss/inference_loss: 2.1443
# Epoch 43/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.3153 - loss/inference_loss: 0.3153 - val_loss: 1.8189 - val_loss/inference_loss: 1.8189
# Epoch 44/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.3054 - loss/inference_loss: 0.3054 - val_loss: 1.5438 - val_loss/inference_loss: 1.5438
# Epoch 45/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 63ms/step - loss: 0.3951 - loss/inference_loss: 0.3951 - val_loss: 0.8452 - val_loss/inference_loss: 0.8452
# Epoch 46/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.3040 - loss/inference_loss: 0.3040 - val_loss: 1.5605 - val_loss/inference_loss: 1.5605
# Epoch 47/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.3631 - loss/inference_loss: 0.3631 - val_loss: 1.1792 - val_loss/inference_loss: 1.1792
# Epoch 48/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.2975 - loss/inference_loss: 0.2975 - val_loss: 1.9351 - val_loss/inference_loss: 1.9351
# Epoch 49/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 48s 123ms/step - loss: 0.2621 - loss/inference_loss: 0.2621 - val_loss: 1.3811 - val_loss/inference_loss: 1.3811
# Epoch 50/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 66ms/step - loss: 0.2370 - loss/inference_loss: 0.2370 - val_loss: 1.1833 - val_loss/inference_loss: 1.1833
# Epoch 51/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.2544 - loss/inference_loss: 0.2544 - val_loss: 0.9340 - val_loss/inference_loss: 0.9340
# Epoch 52/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - loss: 0.2179 - loss/inference_loss: 0.2179 - val_loss: 1.2217 - val_loss/inference_loss: 1.2217
# Epoch 53/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 63ms/step - loss: 0.2109 - loss/inference_loss: 0.2109 - val_loss: 1.2999 - val_loss/inference_loss: 1.2999
# Epoch 54/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - loss: 0.2241 - loss/inference_loss: 0.2241 - val_loss: 1.7060 - val_loss/inference_loss: 1.7060
# Epoch 55/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 45s 116ms/step - loss: 0.2069 - loss/inference_loss: 0.2069 - val_loss: 1.6400 - val_loss/inference_loss: 1.6400
# Epoch 56/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.1932 - loss/inference_loss: 0.1932 - val_loss: 1.1943 - val_loss/inference_loss: 1.1943
# Epoch 57/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.1770 - loss/inference_loss: 0.1770 - val_loss: 0.8762 - val_loss/inference_loss: 0.8762
# Epoch 58/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.1635 - loss/inference_loss: 0.1635 - val_loss: 0.6473 - val_loss/inference_loss: 0.6473
# Epoch 59/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.1355 - loss/inference_loss: 0.1355 - val_loss: 1.3309 - val_loss/inference_loss: 1.3309
# Epoch 60/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.1373 - loss/inference_loss: 0.1373 - val_loss: 1.4941 - val_loss/inference_loss: 1.4941
# Epoch 61/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.1389 - loss/inference_loss: 0.1389 - val_loss: 1.5578 - val_loss/inference_loss: 1.5578
# Epoch 62/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 60ms/step - loss: 0.1342 - loss/inference_loss: 0.1342 - val_loss: 0.6722 - val_loss/inference_loss: 0.6722
# Epoch 63/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.1257 - loss/inference_loss: 0.1257 - val_loss: 0.7094 - val_loss/inference_loss: 0.7094
# Epoch 64/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.1098 - loss/inference_loss: 0.1098 - val_loss: 1.4527 - val_loss/inference_loss: 1.4527
# Epoch 65/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 63ms/step - loss: 0.1007 - loss/inference_loss: 0.1007 - val_loss: 1.4563 - val_loss/inference_loss: 1.4563
# Epoch 66/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.1179 - loss/inference_loss: 0.1179 - val_loss: 1.4639 - val_loss/inference_loss: 1.4639
# Epoch 67/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.1219 - loss/inference_loss: 0.1219 - val_loss: 0.8862 - val_loss/inference_loss: 0.8862
# Epoch 68/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 60ms/step - loss: 0.0992 - loss/inference_loss: 0.0992 - val_loss: 1.7853 - val_loss/inference_loss: 1.7853
# Epoch 69/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 0.0908 - loss/inference_loss: 0.0908 - val_loss: 1.1264 - val_loss/inference_loss: 1.1264
# Epoch 70/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.0798 - loss/inference_loss: 0.0798 - val_loss: 1.3922 - val_loss/inference_loss: 1.3922
# Epoch 71/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.0721 - loss/inference_loss: 0.0721 - val_loss: 1.8667 - val_loss/inference_loss: 1.8667
# Epoch 72/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.0683 - loss/inference_loss: 0.0683 - val_loss: 1.3728 - val_loss/inference_loss: 1.3728
# Epoch 73/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - loss: 0.0684 - loss/inference_loss: 0.0684 - val_loss: 0.8653 - val_loss/inference_loss: 0.8653
# Epoch 74/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.0572 - loss/inference_loss: 0.0572 - val_loss: 2.1542 - val_loss/inference_loss: 2.1542
# Epoch 75/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.0490 - loss/inference_loss: 0.0490 - val_loss: 2.1883 - val_loss/inference_loss: 2.1883
# Epoch 76/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.0504 - loss/inference_loss: 0.0504 - val_loss: 1.9935 - val_loss/inference_loss: 1.9935
# Epoch 77/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.0473 - loss/inference_loss: 0.0473 - val_loss: 2.4620 - val_loss/inference_loss: 2.4620
# Epoch 78/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.0298 - loss/inference_loss: 0.0298 - val_loss: 2.3720 - val_loss/inference_loss: 2.3720
# Epoch 79/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.0345 - loss/inference_loss: 0.0345 - val_loss: 2.4481 - val_loss/inference_loss: 2.4481
# Epoch 80/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.0182 - loss/inference_loss: 0.0182 - val_loss: 1.6107 - val_loss/inference_loss: 1.6107
# Epoch 81/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.0217 - loss/inference_loss: 0.0217 - val_loss: 1.7632 - val_loss/inference_loss: 1.7632
# Epoch 82/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: 0.0132 - loss/inference_loss: 0.0132 - val_loss: 1.9651 - val_loss/inference_loss: 1.9651
# Epoch 83/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 60ms/step - loss: 0.0132 - loss/inference_loss: 0.0132 - val_loss: 1.4242 - val_loss/inference_loss: 1.4242
# Epoch 84/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: 0.0067 - loss/inference_loss: 0.0067 - val_loss: 1.6601 - val_loss/inference_loss: 1.6601
# Epoch 85/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.0028 - loss/inference_loss: 0.0028 - val_loss: 1.4192 - val_loss/inference_loss: 1.4192
# Epoch 86/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: 0.0130 - loss/inference_loss: 0.0130 - val_loss: 1.5299 - val_loss/inference_loss: 1.5299
# Epoch 87/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: -0.0033 - loss/inference_loss: -0.0033 - val_loss: 1.9849 - val_loss/inference_loss: 1.9849
# Epoch 88/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: -0.0098 - loss/inference_loss: -0.0098 - val_loss: 1.6165 - val_loss/inference_loss: 1.6165
# Epoch 89/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: -0.0013 - loss/inference_loss: -0.0013 - val_loss: 1.7672 - val_loss/inference_loss: 1.7672
# Epoch 90/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: -0.0124 - loss/inference_loss: -0.0124 - val_loss: 1.3079 - val_loss/inference_loss: 1.3079
# Epoch 91/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 98ms/step - loss: -0.0057 - loss/inference_loss: -0.0057 - val_loss: 1.6672 - val_loss/inference_loss: 1.6672
# Epoch 92/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 92ms/step - loss: -0.0083 - loss/inference_loss: -0.0083 - val_loss: 1.5690 - val_loss/inference_loss: 1.5690
# Epoch 93/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: -0.0133 - loss/inference_loss: -0.0133 - val_loss: 2.1423 - val_loss/inference_loss: 2.1423
# Epoch 94/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: -0.0122 - loss/inference_loss: -0.0122 - val_loss: 1.6220 - val_loss/inference_loss: 1.6220
# Epoch 95/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: -0.0161 - loss/inference_loss: -0.0161 - val_loss: 1.5831 - val_loss/inference_loss: 1.5831
# Epoch 96/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: -0.0232 - loss/inference_loss: -0.0232 - val_loss: 1.7382 - val_loss/inference_loss: 1.7382
# Epoch 97/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 61ms/step - loss: -0.0078 - loss/inference_loss: -0.0078 - val_loss: 1.6740 - val_loss/inference_loss: 1.6740
# Epoch 98/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: -0.0236 - loss/inference_loss: -0.0236 - val_loss: 2.2644 - val_loss/inference_loss: 2.2644
# Epoch 99/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 24s 62ms/step - loss: -0.0211 - loss/inference_loss: -0.0211 - val_loss: 1.7182 - val_loss/inference_loss: 1.7182
# Epoch 100/100
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - loss: -0.0172 - loss/inference_loss: -0.0172 - val_loss: 1.8458 - val_loss/inference_loss: 1.8458
# INFO:bayesflow:Training is now finished.
#             You can find the trained approximator at '../checkpoints/simons_crazy_net3.simons_crazy_net3.keras'.
#             To load it, use approximator = keras.saving.load_model(...).
# CPU times: user 44min 39s, sys: 58.4 s, total: 45min 38s
# Wall time: 45min 32s

# %% [markdown]
# ## In Silico Validation
# figs = workflow.plot_default_diagnostics(test_data=val_data)

# %%
approximator = keras.saving.load_model("../checkpoints/simons_crazy_net.keras")

figs = workflow.plot_default_diagnostics(test_data=val_data, calibration_ecdf_kwargs=dict(difference=True))

# %%
table = workflow.compute_default_diagnostics(test_data=val_data)
table
# Out:
#                               A       tau      mu_c        t0         b
# NRMSE                  0.128201  0.237923  0.080446  0.022781  0.064084
# Posterior Contraction  0.792813  0.508439  0.915841  0.993922  0.964119
# Calibration Error      0.016842  0.028684  0.060263  0.013421  0.057895

# %%
table = workflow.compute_custom_diagnostics(test_data=val_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 table = workflow.compute_custom_diagnostics(test_data=val_data)
#       3 27*100
#
# TypeError: BasicWorkflow.compute_custom_diagnostics() missing 1 required positional argument: 'metrics'

# %% [markdown]
# ## Custom Stuff

# %%
approximator = keras.saving.load_model("../checkpoints/simons_crazy_net2.keras")

# %%
samples = approximator.sample(conditions=val_data, num_samples=1000)

# %%
sbc = bf.diagnostics.plots.calibration_ecdf(samples, val_data, variable_keys=["A", "tau", "mu_c", "t0", "b"], difference=True)

# %% [markdown]
# ## Real Data Inference

# %%
#TODO

# %% [markdown]
# ## Posterior Predictive Checks

# %%
#TODO
